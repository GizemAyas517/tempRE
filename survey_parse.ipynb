# %%
# Clone the entire repo.
# !git clone -l -s git://github.com/GizemAyas517/tempRE.git cloned-repo
# %cd cloned-repo
# !ls
# Out:
# Cloning into 'cloned-repo'...
# ...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 25 (delta 3), reused 24 (delta 2), pack-reused 0
# Receiving objects: 100% (25/25), 193.25 KiB | 3.79 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/cloned-repo/cloned-repo/cloned-repo/cloned-repo
# 'User Stories 1-2.xlsx'  'User Stories 2-3.xlsx'  'User Stories 4-1.xlsx'
# 'User Stories 1-3.xlsx'  'User Stories 3-1.xlsx'  'User Stories 4-2.xlsx'
# 'User Stories 1-4.xlsx'  'User Stories 3-2.xlsx'  'User Stories 4-3.xlsx'
# 'User Stories 1-5.xlsx'  'User Stories 3-3.xlsx'  'User Stories 4-4.xlsx'
# 'User Stories 2-1.xlsx'  'User Stories 3-4.xlsx'  'User Stories 4-5.xlsx'
# 'User Stories 2-2.xlsx'  'User Stories 3-5.xlsx'

# %%
import pandas as pd
ex1 = pd.read_excel("User Stories 1-2.xlsx")
ex2 = pd.read_excel("User Stories 2-2.xlsx")
ex3 = pd.read_excel("User Stories 3-2.xlsx")
ex4 = pd.read_excel("User Stories 4-2.xlsx")
ex1.columns = ["text", "pronouns", "noun1", "noun2", "noun3"]
ex2.columns = ["text", "pronouns", "noun1", "noun2", "noun3"]
ex3.columns = ["text", "pronouns", "noun1", "noun2", "noun3"]
ex4.columns = ["text", "pronouns", "noun1", "noun2", "noun3"]
for i in range(49):
  print(ex1.loc[i].text)
  for index,noun in enumerate(ex1.loc[i].pronouns[1:-1].replace("\"","").replace("'","").split(",")):
      print("noun= "+ noun, end="\t")
      print(" %s" %ex1.loc[i]["noun"+ str(index+1)],end="; ")
      print(" %s" %ex2.loc[i]["noun"+ str(index+1)],end="; ")
      print(" %s" %ex3.loc[i]["noun"+ str(index+1)],end="; ")
      print(" %s" %ex4.loc[i]["noun"+ str(index+1)],end="; ")
      print(" ")
     
    
  print("\n--------------------\n")
# Out:
# As a trainer, I want to delete one of my courses or events, so that it's no longer listed if I cancel for some reason.
#
# noun= its	 one of my courses or events;  one of my courses or events;  one of my courses or events;  courses;
#
# --------------------
#
# As a visitor, I want to download presentations, PDFs, etc. on Scrum, so that I can learn from them or use them.
#
# noun= them	 presentations, PDFS;  presentations, PDF's, etc. on Scrum;  presentations, PDFs, etc.;  presentations;
#
# --------------------
#
# As a site admin, I want to approve each help wanted ad before it gets to the site, so that we're sure of the quality of jobs being listed.
#
# noun= it	 help wanted ad;  help wanted ad;  help wanted ad;  help wanted ad;
#
# --------------------
#
# As a site admin, I want to be emailed whenever a job is submitted, so that I am aware of it and can decide if I want to post it.
#
# noun= it	 job;  job;  a job;  job;
#
# --------------------
#
# ...

# %%
ex1 = pd.read_excel("User Stories 1-3.xlsx")
ex2 = pd.read_excel("User Stories 2-3.xlsx")
ex3 = pd.read_excel("User Stories 3-3.xlsx")
ex4 = pd.read_excel("User Stories 4-3.xlsx")
ex1.columns = ["text", "pronouns", "noun1", "noun2", "noun3"]
ex2.columns = ["text", "pronouns", "noun1", "noun2", "noun3"]
ex3.columns = ["text", "pronouns", "noun1", "noun2", "noun3"]
ex4.columns = ["text", "pronouns", "noun1", "noun2", "noun3"]
for i in range(51):
  print(ex1.loc[i].text)
  for index,noun in enumerate(ex1.loc[i].pronouns[1:-1].replace("\"","").replace("'","").split(",")):
      print("noun= "+ noun, end="\t")
      print(" %s" %ex1.loc[i]["noun"+ str(index+1)],end="; ")
      print(" %s" %ex2.loc[i]["noun"+ str(index+1)],end="; ")
      print(" %s" %ex3.loc[i]["noun"+ str(index+1)],end="; ")
      print(" %s" %ex4.loc[i]["noun"+ str(index+1)],end="; ")
      print(" ")
     
    
  print("\n--------------------\n")
# Out:
# As a Publisher, I want to publish a data package in the UI, so that that it is available and published.
#
# noun= it	 a data package;  data package;  Data Package;  a data package;
#
# --------------------
#
# As a Publisher, I want to create a data package in the UI so that it is available and published.
#
# noun= it	 a data package;  data package;  Data Package;  a data package;
#
# --------------------
#
# As a Publisher, I want to be able to restore the deleted data package via cli, so that that it is back visible and available to view, download.
#
# noun= it	 the deleted data package;  deleted data package;  Deleted Data Package;  the deleted data package;
#
# --------------------
#
# As a publisher, I want to show the world how my published data is, so that that it immediately catches consumer's attention.
#
# noun= it	 my published data;  my published data;  My Published Data;  my published data;
#
# --------------------
#
# ...

# %%
ex1 = pd.read_excel("User Stories 1-4.xlsx")
#ex2 = pd.read_excel("User Stories 2-4.xlsx")
ex3 = pd.read_excel("User Stories 3-4.xlsx")
ex4 = pd.read_excel("User Stories 4-4.xlsx")
ex1.columns = ["text", "pronouns", "noun1", "noun2", "noun3"]
#ex2.columns = ["text", "pronouns", "noun1", "noun2", "noun3"]
ex3.columns = ["text", "pronouns", "noun1", "noun2", "noun3"]
ex4.columns = ["text", "pronouns", "noun1", "noun2", "noun3"]

for i in range(51):
  print(ex1.loc[i].text)
  for index,noun in enumerate(ex1.loc[i].pronouns[1:-1].replace("\"","").replace("'","").split(",")):
      print("noun= "+ noun, end="\t")
      print(" %s" %ex1.loc[i]["noun"+ str(index+1)],end="; ")
#      print(" %s" %ex2.loc[i]["noun"+ str(index+1)],end="; ")
      print(" %s" %ex3.loc[i]["noun"+ str(index+1)],end="; ")
      print(" %s" %ex4.loc[i]["noun"+ str(index+1)],end="; ")
      print(" ")
     
    
  print("\n--------------------\n")
# Out:
# As an OlderPerson, I want to have ALFRED to initiate questions, but it should be in the domains of my interest such as cinema, exhibitions, cooking.
#
# noun= it	 ALFRED or questions;  ALFRED;  Questions;
#
# --------------------
#
# As an OlderPerson, I want to use ALFRED to get a personalized invitation to a social event, so that it motivates more to go.
#
# noun= it	 ALFED or personalized invitation;  ALFRED;  Personalized invitation;
#
# --------------------
#
# As an InformalCaregiver, I want to have a game that the carer could play together with the user, so that it would enable to monitor the users’ state of health but also have some fun time.
#
# noun= it	 game;  game;  Game  ;
#
# --------------------
#
# As a developer, I want to have the API components to be on a high level so that I don’t have to deal with their details.
#
# noun= their	 API components ;  API components;  API components ;
#
# --------------------
#
# ...
